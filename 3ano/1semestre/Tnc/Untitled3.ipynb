# %%
p = 61129 
Zp=IntegerModRing(p)
multiplicative_order(Zp(13646))
# Out:
# 61128

# %%
(p, r, b)=( 1262804383 , 6 , 676027718 )
Zp=IntegerModRing(p)
r=Zp(r)
b=Zp(b)
gama,delta = Zp( 932022663) , ( 910483139  )
a=discrete_log(b,r)
(1/gama)^a*delta
# Out:
# 85

# %%
p= 14429568937645027039
Zp = IntegerModRing(p)
b= Zp(2552336463867099405)
r=Zp(6)
discrete_log(b,r)
# Out:
# 655346690670059083

# %%
n = 93991
Zp=IntegerModRing(n)
b1,b2,b3,b4=Zp(11822),Zp(85063),Zp(55273),Zp(1460)

b4^((n-1)/2),jacobi_symbol(b4,n)
# Out:
# (93990, -1)
