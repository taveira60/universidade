# %%
p = 44491
Zp=IntegerModRing(p)
a=Zp(535)
multiplicative_order(a)
# Out:
# 44490

# %%
 p= 17326967367196526087
Zp=IntegerModRing(p)
b= Zp(2626655245610212378)
r= Zp(5)
discrete_log(b,r)
# Out:
# 9618043386048889669

# %%
(p, r, b)=( 4091862497 , 3 , 812145079 )
Zp=IntegerModRing(p)
r=Zp(r)
b=Zp(b)
g,d = Zp( 1252632050) , Zp(3321716145 ) 
a=discrete_log(b,r)

(1/g)^a*d
# Out:
# 81
